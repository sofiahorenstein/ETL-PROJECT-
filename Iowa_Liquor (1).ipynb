# %%
import pandas as pd

# %%
iowa_liquor=pd.read_csv('Iowa_Liquor_Sales.csv')
# Out:
# /Users/sofiecoopersmith/anaconda3/envs/PythonData/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
iowa_liquor.head()
# Out:
#   Invoice/Item Number        Date  Store Number  \
# 0        S29198800001  11/20/2015          2191
# 1        S29195400002  11/21/2015          2205
# 2        S29050300001  11/16/2015          3549
# 3        S28867700001  11/04/2015          2513
# 4        S29050800001  11/17/2015          3942
#
#                          Store Name              Address          City  \
# 0                    Keokuk Spirits            1013 MAIN        KEOKUK
# 1            Ding's Honk And Holler     900 E WASHINGTON      CLARINDA
# 2              Quicker Liquor Store         1414 48TH ST  FORT MADISON
# 3  Hy-Vee Food Store #2 / Iowa City       812  S 1ST AVE     IOWA CITY
# 4                  Twin Town Liquor  104 HIGHWAY 30 WEST        TOLEDO
#
#   Zip Code                                     Store Location  County Number  \
# 0    52632    1013 MAIN\nKEOKUK 52632\n(40.39978, -91.387531)           56.0
# 1    51632  900 E WASHINGTON\nCLARINDA 51632\n(40.739238, ...           73.0
# ...

# %%
iowa_liquor.keys()
# Out:
# Index(['Invoice/Item Number', 'Date', 'Store Number', 'Store Name', 'Address',
#        'City', 'Zip Code', 'Store Location', 'County Number', 'County',
#        'Category', 'Category Name', 'Vendor Number', 'Vendor Name',
#        'Item Number', 'Item Description', 'Pack', 'Bottle Volume (ml)',
#        'State Bottle Cost', 'State Bottle Retail', 'Bottles Sold',
#        'Sale (Dollars)', 'Volume Sold (Liters)', 'Volume Sold (Gallons)'],
#       dtype='object')

# %%
liquor_prep_brands=liquor_prep[["Item Description"]]
liquor_prep_brands
# Out:
#                                           Item Description
# 0                                    Templeton Rye w/Flask
# 1                                    Templeton Rye w/Flask
# 2            Disaronno Amaretto Cavalli Mignon 3-50ml Pack
# 3                           Knob Creek w/ Crystal Decanter
# 4            Disaronno Amaretto Cavalli Mignon 3-50ml Pack
# ...                                                    ...
# 12591072                     FrappaChata Iced Coffee Blend
# 12591073                            Old Forester Statesman
# 12591074               Old Forester 1897 Whisky Row Series
# 12591075               Old Forester 1870 Whisky Row Series
# 12591076  Sugarlands Shine Peanut Butter & Jelly Moonshine
#
# [12591077 rows x 1 columns]

# %%
iowa_liquor.isnull().sum(axis = 0)
# Out:
# Invoice/Item Number          0
# Date                         0
# Store Number                 0
# Store Name                   0
# Address                   2376
# City                      2375
# Zip Code                  2420
# Store Location            2375
# County Number            79178
# County                   79178
# Category                  8020
# Category Name            16086
# Vendor Number                3
# Vendor Name                  1
# Item Number                  0
# Item Description             0
# Pack                         0
# Bottle Volume (ml)           0
# State Bottle Cost           10
# State Bottle Retail         10
# Bottles Sold                 0
# Sale (Dollars)              10
# Volume Sold (Liters)         0
# Volume Sold (Gallons)        0
# dtype: int64

# %%
iowa_liquor_drop=iowa_liquor.dropna(subset=["County Number"])

# %%
iowa_liquor_drop.isnull().sum(axis = 0)
# Out:
# Invoice/Item Number          0
# Date                         0
# Store Number                 0
# Store Name                   0
# Address                      1
# City                         0
# Zip Code                     0
# Store Location               0
# County Number                0
# County                       0
# Category                  8016
# Category Name            15912
# Vendor Number                3
# Vendor Name                  1
# Item Number                  0
# Item Description             0
# Pack                         0
# Bottle Volume (ml)           0
# State Bottle Cost           10
# State Bottle Retail         10
# Bottles Sold                 0
# Sale (Dollars)              10
# Volume Sold (Liters)         0
# Volume Sold (Gallons)        0
# dtype: int64

# %%
iowa_liquor_drop.count()
# Out:
# Invoice/Item Number      12511899
# Date                     12511899
# Store Number             12511899
# Store Name               12511899
# Address                  12511898
# City                     12511899
# Zip Code                 12511899
# Store Location           12511899
# County Number            12511899
# County                   12511899
# Category                 12503883
# Category Name            12495987
# Vendor Number            12511896
# Vendor Name              12511898
# Item Number              12511899
# Item Description         12511899
# Pack                     12511899
# Bottle Volume (ml)       12511899
# State Bottle Cost        12511889
# State Bottle Retail      12511889
# Bottles Sold             12511899
# Sale (Dollars)           12511889
# Volume Sold (Liters)     12511899
# Volume Sold (Gallons)    12511899
# dtype: int64

# %%
iowa_liquor_drop_2=iowa_liquor_drop.dropna(subset=["Category Name"])

# %%
iowa_liquor_drop_2.count()
# Out:
# Invoice/Item Number      12574991
# Date                     12574991
# Store Number             12574991
# Store Name               12574991
# Address                  12572619
# City                     12572620
# Zip Code                 12572575
# Store Location           12572620
# County Number            12495987
# County                   12495987
# Category                 12574991
# Category Name            12574991
# Vendor Number            12574989
# Vendor Name              12574991
# Item Number              12574991
# Item Description         12574991
# Pack                     12574991
# Bottle Volume (ml)       12574991
# State Bottle Cost        12574981
# State Bottle Retail      12574981
# Bottles Sold             12574991
# Sale (Dollars)           12574981
# Volume Sold (Liters)     12574991
# Volume Sold (Gallons)    12574991
# dtype: int64

# %%
iowa_liquor_drop_2.isnull().sum(axis = 0)
# Out:
# Invoice/Item Number       0
# Date                      0
# Store Number              0
# Store Name                0
# Address                   1
# City                      0
# Zip Code                  0
# Store Location            0
# County Number             0
# County                    0
# Category                  0
# Category Name             0
# Vendor Number             2
# Vendor Name               0
# Item Number               0
# Item Description          0
# Pack                      0
# Bottle Volume (ml)        0
# State Bottle Cost        10
# State Bottle Retail      10
# Bottles Sold              0
# Sale (Dollars)           10
# Volume Sold (Liters)      0
# Volume Sold (Gallons)     0
# dtype: int64
